# %%
#from google.colab import drive
#drive.mount('/content/gdrive')
#%cd #file path here or go through each

# %%
# !pip3 uninstall PyTorch
# !pip3 install https://download.pytorch.org/whl/cu80/torch-0.1.12.post2-cp36-cp36m-linux_x86_64.whl
# Out:
# WARNING: Skipping PyTorch as it is not installed.
# Defaulting to user installation because normal site-packages is not writeable
# ERROR: torch-0.1.12.post2-cp36-cp36m-linux_x86_64.whl is not a supported wheel on this platform.

# %%
# %ls
# Out:
#  Le volume dans le lecteur C s'appelle OS
#  Le num�ro de s�rie du volume est AEF5-3049
#
#  R�pertoire de c:\Users\brahi\Documents\Panification_en_Intelligence_Artificielle\Breakout_A3C-master
#
# 25/03/2026  02:22    <DIR>          .
# 22/03/2026  22:23    <DIR>          ..
# 25/03/2026  02:22    <DIR>          .vscode
# 25/03/2026  02:25    <DIR>          __pycache__
# 22/03/2026  22:23           108�532 breakout.png
# 25/03/2026  02:06             6�873 Breakout_Run.ipynb
# 25/03/2026  02:17             4�682 envs.py
# 23/03/2026  12:29             1�859 main.py
# 22/03/2026  22:23    <DIR>          Model
# 25/03/2026  02:17             2�805 model.py
# 23/03/2026  12:29             2�331 my_optim.py
# 22/03/2026  22:23             3�309 README.md
# 22/03/2026  22:23    <DIR>          test
# 25/03/2026  00:50             1�691 test.py
# 25/03/2026  00:50             4�789 train.py
#                9 fichier(s)          136�871 octets
#                6 R�p(s)  718�517�403�648 octets libres

# %%
# %cd ..
# Out:
# c:\Users\brahi\Documents\Panification_en_Intelligence_Artificielle

# %%
# %ls
# Out:
#  Le volume dans le lecteur C s'appelle OS
#  Le num�ro de s�rie du volume est AEF5-3049
#
#  R�pertoire de c:\Users\brahi\Documents\Panification_en_Intelligence_Artificielle
#
# 22/03/2026  22:23    <DIR>          .
# 11/03/2026  14:29    <DIR>          ..
# 11/02/2026  15:18           249�287 A3C.pdf
# 25/03/2026  02:22    <DIR>          Breakout_A3C-master
# 19/01/2026  20:46         2�613�898 Chapitre 2 - MDP.pdf
# 19/01/2026  20:55         2�887�892 Chapitre 3 - RL v2.pdf
# 19/01/2026  20:54         1�408�588 Chapitre 4 - Deep_Q-Learning.pdf
# 05/01/2026  18:42    <DIR>          Chapitre1_introduction
# 19/01/2026  20:54         2�165�047 Compl�ment - Les RNs.pdf
# 17/02/2026  20:17    <DIR>          Devoir 1
# 19/01/2026  20:46           530�084 Devoir 1 -Description du travail et modalit�s des livrables.pdf
# 19/01/2026  20:58    <DIR>          Exemples_IO
# 19/01/2026  20:53            20�353 Exemples_IO.zip
# 05/01/2026  18:44           430�314 IFT608 - Plan de cours H26.pdf
# 14/01/2026  00:03         2�275�080 IFT608-702 - Introduction - Compl�ment 2.pdf
# 19/01/2026  20:46         1�040�492 IFT608-702 - TP1 - Description.pdf
# 05/01/2026  18:42    <DIR>          Livres
# 05/01/2026  18:43    <DIR>          Pr�requis
# 07/02/2026  16:05           473�454 Projet.pdf
#               11 fichier(s)       14�094�489 octets
#                8 R�p(s)  718�517�272�576 octets libres

# %%
# %cd content/gdrive/My Drive/A3C - Breakout
# Out:
# [WinError 3] Le chemin d’accès spécifié est introuvable: 'content/gdrive/My Drive/A3C - Breakout'
# c:\Users\brahi\Documents\Panification_en_Intelligence_Artificielle

# %%
# %cd Code_No_Comment
# Out:
# [WinError 2] Le fichier spécifié est introuvable: 'Code_No_Comment'
# c:\Users\brahi\Documents\Panification_en_Intelligence_Artificielle

# %%
# !pip install gym==0.9.3
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: gym==0.9.3 in C:\Users\brahi\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (0.9.3)
# Requirement already satisfied: numpy>=1.10.4 in C:\Users\brahi\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from gym==0.9.3) (2.3.4)
# Requirement already satisfied: requests>=2.0 in C:\Users\brahi\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from gym==0.9.3) (2.32.5)
# Requirement already satisfied: six in C:\Users\brahi\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from gym==0.9.3) (1.17.0)
# Requirement already satisfied: pyglet>=1.2.0 in C:\Users\brahi\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from gym==0.9.3) (2.1.13)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\brahi\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from requests>=2.0->gym==0.9.3) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\brahi\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from requests>=2.0->gym==0.9.3) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in C:\Users\brahi\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from requests>=2.0->gym==0.9.3) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in C:\Users\brahi\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from requests>=2.0->gym==0.9.3) (2025.11.12)

# %%
# !python main.py
# Out:
# python: can't open file 'c:\\Users\\brahi\\Documents\\Panification_en_Intelligence_Artificielle\\main.py': [Errno 2] No such file or directory
