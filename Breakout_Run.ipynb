# %%
#from google.colab import drive
#drive.mount('/content/gdrive')
#%cd #file path here or go through each

# %%
# !pip3 uninstall PyTorch
# !pip3 install https://download.pytorch.org/whl/cu80/torch-0.1.12.post2-cp36-cp36m-linux_x86_64.whl
# Out:
# WARNING: Skipping PyTorch as it is not installed.
#
# [notice] A new release of pip is available: 24.3.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: torch-0.1.12.post2-cp36-cp36m-linux_x86_64.whl is not a supported wheel on this platform.

# %%
# %ls
# Out:
#  Le volume dans le lecteur C s'appelle Windows
#  Le num�ro de s�rie du volume est DA8D-C3C9
#
#  R�pertoire de c:\Users\brao6674\Algo_A3C
#
# 2026-04-08  11:02    <DIR>          .
# 2026-04-08  11:18    <DIR>          ..
# 2026-04-08  11:02    <DIR>          .vscode
# 2026-04-08  11:13    <DIR>          __pycache__
# 2026-04-08  11:02           108�532 breakout.png
# 2026-04-08  11:02            12�338 Breakout_Run.ipynb
# 2026-04-08  11:02             8�961 envs.py
# 2026-04-08  11:12             3�784 main.py
# 2026-04-08  11:02    <DIR>          Model
# 2026-04-08  11:02             3�026 model.py
# 2026-04-08  11:02             3�380 model_dueling.py
# 2026-04-08  11:02             2�380 my_optim.py
# 2026-04-08  11:02             3�389 README.md
# 2026-04-08  11:02           111�882 Resultats.ipynb
# 2026-04-08  11:02            25�409 results_dueling.txt
# 2026-04-08  11:02            39�759 results_standard.txt
# 2026-04-08  11:02           364�814 sp�cification.pdf
# 2026-04-08  11:02    <DIR>          test
# 2026-04-08  11:02             2�851 test.py
# 2026-04-08  11:02             2�906 test_dueling.py
# 2026-04-08  11:02             6�854 train.py
# 2026-04-08  11:02             4�988 train_dueling.py
#               16 fichier(s)          705�253 octets
#                6 R�p(s)  82�752�782�336 octets libres

# %%
# %cd ..
# Out:
# c:\Users\brao6674

# %%
# %ls
# Out:
#  Le volume dans le lecteur C s'appelle Windows
#  Le num�ro de s�rie du volume est DA8D-C3C9
#
#  R�pertoire de c:\Users\brao6674
#
# 2026-04-08  11:18    <DIR>          .
# 2026-04-08  10:28    <DIR>          ..
# 2024-11-04  10:18             3�597 .boris
# 2024-12-20  14:17    <DIR>          .dotnet
# 2024-11-18  10:15    <DIR>          .imagej
# 2026-04-08  11:18    <DIR>          .ipython
# 2026-04-08  10:40    <DIR>          .ms-ad
# 2026-04-08  10:28                 0 .uc-c81f651d0436c83a1264ef796532e6f0.brao6674.dinf-1017-10a.tmp
# 2026-04-08  10:59    <DIR>          .vscode
# 2026-04-08  11:02    <DIR>          Algo_A3C
# 2026-04-08  10:28    <DIR>          Contacts
# 2026-04-08  10:28    <DIR>          Desktop
# 2026-04-08  10:28    <DIR>          Documents
# 2026-04-08  10:59    <DIR>          Downloads
# 2026-04-08  10:28    <DIR>          Favorites
# 2026-04-08  10:28    <DIR>          Links
# 2026-04-08  10:28    <DIR>          Music
# 2024-10-09  10:35    <DIR>          OneDrive
# 2026-04-08  10:28    <DIR>          Pictures
# 2026-04-08  10:28    <DIR>          Saved Games
# 2026-04-08  10:28    <DIR>          Searches
# 2026-04-08  10:28    <DIR>          Videos
# 2024-11-04  14:15    <DIR>          wekafiles
#                2 fichier(s)            3�597 octets
#               21 R�p(s)  82�752�782�336 octets libres

# %%
# %cd content/gdrive/My Drive/A3C - Breakout
# Out:
# [WinError 3] Le chemin d’accès spécifié est introuvable: 'content/gdrive/My Drive/A3C - Breakout'
# c:\Users\brao6674

# %%
# %cd Code_No_Comment
# Out:
# [WinError 2] Le fichier spécifié est introuvable: 'Code_No_Comment'
# c:\Users\brao6674

# %%
# !pip install gym==0.9.3
# Out:
# Collecting gym==0.9.3
#   Downloading gym-0.9.3.tar.gz (157 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: numpy>=1.10.4 in c:\python312\lib\site-packages (from gym==0.9.3) (2.4.4)
# Collecting requests>=2.0 (from gym==0.9.3)
#   Downloading requests-2.33.1-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: six in c:\users\brao6674\appdata\roaming\python\python312\site-packages (from gym==0.9.3) (1.17.0)
# Collecting pyglet>=1.2.0 (from gym==0.9.3)
#   Downloading pyglet-2.1.14-py3-none-any.whl.metadata (7.7 kB)
# Collecting charset_normalizer<4,>=2 (from requests>=2.0->gym==0.9.3)
#   Downloading charset_normalizer-3.4.7-cp312-cp312-win_amd64.whl.metadata (41 kB)
# Collecting idna<4,>=2.5 (from requests>=2.0->gym==0.9.3)
#   Downloading idna-3.11-py3-none-any.whl.metadata (8.4 kB)
# Collecting urllib3<3,>=1.26 (from requests>=2.0->gym==0.9.3)
#   Downloading urllib3-2.6.3-py3-none-any.whl.metadata (6.9 kB)
# Collecting certifi>=2023.5.7 (from requests>=2.0->gym==0.9.3)
#   Downloading certifi-2026.2.25-py3-none-any.whl.metadata (2.5 kB)
# Downloading pyglet-2.1.14-py3-none-any.whl (1.0 MB)
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    ---------------------------------------- 1.0/1.0 MB 24.1 MB/s eta 0:00:00
# Downloading requests-2.33.1-py3-none-any.whl (64 kB)
# Downloading certifi-2026.2.25-py3-none-any.whl (153 kB)
# Downloading charset_normalizer-3.4.7-cp312-cp312-win_amd64.whl (159 kB)
# Downloading idna-3.11-py3-none-any.whl (71 kB)
# Downloading urllib3-2.6.3-py3-none-any.whl (131 kB)
# Building wheels for collected packages: gym
#   Building wheel for gym (pyproject.toml): started
#   Building wheel for gym (pyproject.toml): finished with status 'done'
#   Created wheel for gym: filename=gym-0.9.3-py3-none-any.whl size=215983 sha256=b7a6e4f71ed7e522392cf481990a29310b575e33823d32327a56d1c1c4fe670a
#   Stored in directory: c:\users\brao6674\appdata\local\pip\cache\wheels\5d\70\21\272db5de35eceaf3fbe47b1e0a8326c77debdab57cfcae110d
# Successfully built gym
# Installing collected packages: urllib3, pyglet, idna, charset_normalizer, certifi, requests, gym
#   Attempting uninstall: gym
#     Found existing installation: gym 0.26.2
#     Uninstalling gym-0.26.2:
#       Successfully uninstalled gym-0.26.2
# Successfully installed certifi-2026.2.25 charset_normalizer-3.4.7 gym-0.9.3 idna-3.11 pyglet-2.1.14 requests-2.33.1 urllib3-2.6.3
# [notice] A new release of pip is available: 24.3.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !python main.py
# Out:
# python: can't open file 'c:\\Users\\brao6674\\main.py': [Errno 2] No such file or directory

# %%
# !python "C:\Users\brao6674\Algo_A3C\main.py"
# Out:
# ^C
